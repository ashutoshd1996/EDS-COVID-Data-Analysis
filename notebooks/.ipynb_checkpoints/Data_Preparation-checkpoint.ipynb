# %%
import pandas as pd
import numpy as np
from datetime import datetime
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ![CRISP_DM](../reports/figures/CRISP_DM.png)

# %% [markdown]
# # Data Preparation

# %% [markdown]
# * Focus is to understand the final data structure
# * support each step by visual analytics

# %% [markdown]
# git clone/pull https://github.com/CSSEGISandData/COVID-19.git

# %%
data_path = '../data/raw/COVID-19/time_series_covid19_confirmed_global.csv'
pd_raw = pd.read_csv(data_path)

# %%
pd_raw.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  7/15/22  7/16/22  7/17/22  \
# 0        0        0        0        0  ...   183407   183445   183572
# 1        0        0        0        0  ...   293917   293917   293917
# 2        0        0        0        0  ...   266392   266424   266445
# 3        0        0        0        0  ...    44671    44671    44671
# 4        0        0        0        0  ...   101901   101901   101901
#
#    7/18/22  7/19/22  7/20/22  7/21/22  7/22/22  7/23/22  7/24/22
# 0   183687   183908   184038   184224   184360   184473   184587
# 1   293917   293917   293917   293917   293917   293917   293917
# 2   266487   266542   266591   266654   266700   266772   266839
# 3    45061    45061    45061    45326    45326    45326    45326
# 4   102209   102209   102209   102209   102301   102301   102301
#
# [5 rows x 919 columns]

# %%
time_idx  = pd_raw.columns[4:]

# %%
df_plot = pd.DataFrame({'date':time_idx})
df_plot.head()
# Out:
#       date
# 0  1/22/20
# 1  1/23/20
# 2  1/24/20
# 3  1/25/20
# 4  1/26/20

# %%
pd_raw['Country/Region']
# Out:
# 0                           Afghanistan
# 1                               Albania
# 2                               Algeria
# 3                               Andorra
# 4                                Angola
# 5                            Antarctica
# 6                   Antigua and Barbuda
# 7                             Argentina
# 8                               Armenia
# 9                             Australia
# 10                            Australia
# 11                            Australia
# 12                            Australia
# 13                            Australia
# 14                            Australia
# 15                            Australia
# 16                            Australia
# 17                              Austria
# 18                           Azerbaijan
# 19                              Bahamas
# 20                              Bahrain
# 21                           Bangladesh
# 22                             Barbados
# 23                              Belarus
# 24                              Belgium
# 25                               Belize
# 26                                Benin
# 27                               Bhutan
# 28                              Bolivia
# 29               Bosnia and Herzegovina
# 30                             Botswana
# 31                               Brazil
# 32                               Brunei
# 33                             Bulgaria
# 34                         Burkina Faso
# 35                                Burma
# 36                              Burundi
# 37                           Cabo Verde
# 38                             Cambodia
# 39                             Cameroon
# 40                               Canada
# 41                               Canada
# 42                               Canada
# 43                               Canada
# 44                               Canada
# 45                               Canada
# 46                               Canada
# 47                               Canada
# 48                               Canada
# 49                               Canada
# 50                               Canada
# 51                               Canada
# 52                               Canada
# 53                               Canada
# 54                               Canada
# 55                               Canada
# 56             Central African Republic
# 57                                 Chad
# 58                                Chile
# 59                                China
# 60                                China
# 61                                China
# 62                                China
# 63                                China
# 64                                China
# 65                                China
# 66                                China
# 67                                China
# 68                                China
# 69                                China
# 70                                China
# 71                                China
# 72                                China
# 73                                China
# 74                                China
# 75                                China
# 76                                China
# 77                                China
# 78                                China
# 79                                China
# 80                                China
# 81                                China
# 82                                China
# 83                                China
# 84                                China
# 85                                China
# 86                                China
# 87                                China
# 88                                China
# 89                                China
# 90                                China
# 91                                China
# 92                                China
# 93                             Colombia
# 94                              Comoros
# 95                  Congo (Brazzaville)
# 96                     Congo (Kinshasa)
# 97                           Costa Rica
# 98                        Cote d'Ivoire
# 99                              Croatia
# 100                                Cuba
# 101                              Cyprus
# 102                             Czechia
# 103                             Denmark
# 104                             Denmark
# 105                             Denmark
# 106                    Diamond Princess
# 107                            Djibouti
# 108                            Dominica
# 109                  Dominican Republic
# 110                             Ecuador
# 111                               Egypt
# 112                         El Salvador
# 113                   Equatorial Guinea
# 114                             Eritrea
# 115                             Estonia
# 116                            Eswatini
# 117                            Ethiopia
# 118                                Fiji
# 119                             Finland
# 120                              France
# 121                              France
# 122                              France
# 123                              France
# 124                              France
# 125                              France
# 126                              France
# 127                              France
# 128                              France
# 129                              France
# 130                              France
# 131                              France
# 132                               Gabon
# 133                              Gambia
# 134                             Georgia
# 135                             Germany
# 136                               Ghana
# 137                              Greece
# 138                             Grenada
# 139                           Guatemala
# 140                              Guinea
# 141                       Guinea-Bissau
# 142                              Guyana
# 143                               Haiti
# 144                            Holy See
# 145                            Honduras
# 146                             Hungary
# 147                             Iceland
# 148                               India
# 149                           Indonesia
# 150                                Iran
# 151                                Iraq
# 152                             Ireland
# 153                              Israel
# 154                               Italy
# 155                             Jamaica
# 156                               Japan
# 157                              Jordan
# 158                          Kazakhstan
# 159                               Kenya
# 160                            Kiribati
# 161                        Korea, North
# 162                        Korea, South
# 163                              Kosovo
# 164                              Kuwait
# 165                          Kyrgyzstan
# 166                                Laos
# 167                              Latvia
# 168                             Lebanon
# 169                             Lesotho
# 170                             Liberia
# 171                               Libya
# 172                       Liechtenstein
# 173                           Lithuania
# 174                          Luxembourg
# 175                          MS Zaandam
# 176                          Madagascar
# 177                              Malawi
# 178                            Malaysia
# 179                            Maldives
# 180                                Mali
# 181                               Malta
# 182                    Marshall Islands
# 183                          Mauritania
# 184                           Mauritius
# 185                              Mexico
# 186                          Micronesia
# 187                             Moldova
# 188                              Monaco
# 189                            Mongolia
# 190                          Montenegro
# 191                             Morocco
# 192                          Mozambique
# 193                             Namibia
# 194                               Nepal
# 195                         Netherlands
# 196                         Netherlands
# 197                         Netherlands
# 198                         Netherlands
# 199                         Netherlands
# 200                         New Zealand
# 201                         New Zealand
# 202                           Nicaragua
# 203                               Niger
# 204                             Nigeria
# 205                     North Macedonia
# 206                              Norway
# 207                                Oman
# 208                            Pakistan
# 209                               Palau
# 210                              Panama
# 211                    Papua New Guinea
# 212                            Paraguay
# 213                                Peru
# 214                         Philippines
# 215                              Poland
# 216                            Portugal
# 217                               Qatar
# 218                             Romania
# 219                              Russia
# 220                              Rwanda
# 221               Saint Kitts and Nevis
# 222                         Saint Lucia
# 223    Saint Vincent and the Grenadines
# 224                               Samoa
# 225                          San Marino
# 226               Sao Tome and Principe
# 227                        Saudi Arabia
# 228                             Senegal
# 229                              Serbia
# 230                          Seychelles
# 231                        Sierra Leone
# 232                           Singapore
# 233                            Slovakia
# 234                            Slovenia
# 235                     Solomon Islands
# 236                             Somalia
# 237                        South Africa
# 238                         South Sudan
# 239                               Spain
# 240                           Sri Lanka
# 241                               Sudan
# 242                Summer Olympics 2020
# 243                            Suriname
# 244                              Sweden
# 245                         Switzerland
# 246                               Syria
# 247                             Taiwan*
# 248                          Tajikistan
# 249                            Tanzania
# 250                            Thailand
# 251                         Timor-Leste
# 252                                Togo
# 253                               Tonga
# 254                 Trinidad and Tobago
# 255                             Tunisia
# 256                              Turkey
# 257                                  US
# 258                              Uganda
# 259                             Ukraine
# 260                United Arab Emirates
# 261                      United Kingdom
# 262                      United Kingdom
# 263                      United Kingdom
# 264                      United Kingdom
# 265                      United Kingdom
# 266                      United Kingdom
# 267                      United Kingdom
# 268                      United Kingdom
# 269                      United Kingdom
# 270                      United Kingdom
# 271                      United Kingdom
# 272                      United Kingdom
# 273                      United Kingdom
# 274                      United Kingdom
# 275                             Uruguay
# 276                          Uzbekistan
# 277                             Vanuatu
# 278                           Venezuela
# 279                             Vietnam
# 280                  West Bank and Gaza
# 281                Winter Olympics 2022
# 282                               Yemen
# 283                              Zambia
# 284                            Zimbabwe
# Name: Country/Region, dtype: object

# %%
pd_raw[pd_raw['Country/Region']=='Germany'].iloc[:,4::].sum(axis=0)
# Out:
# 1/22/20           0
# 1/23/20           0
# 1/24/20           0
# 1/25/20           0
# 1/26/20           0
#              ...
# 7/20/22    30131303
# 7/21/22    30239122
# 7/22/22    30331131
# 7/23/22    30331133
# 7/24/22    30331133
# Length: 915, dtype: int64

# %%
country_list = ['Italy','US','Spain','Germany','Korea, South']

# %%
for each in country_list:
    df_plot[each] = np.array(pd_raw[pd_raw['Country/Region']==each].iloc[:,4::].sum(axis=0))

# %%
df_plot.set_index('date').plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Data Type Date

# %%
df_plot.head()
# Out:
#       date  Italy  US  Spain  Germany  Korea, South
# 0  1/22/20      0   1      0        0             1
# 1  1/23/20      0   1      0        0             1
# 2  1/24/20      0   2      0        0             2
# 3  1/25/20      0   2      0        0             2
# 4  1/26/20      0   5      0        0             3

# %%
time_idx = [datetime.strptime(each,"%m/%d/%y") for each in df_plot.date] #Converting to datetime object
time_str=[each.strftime('%Y-%m-%d') for each in time_idx] # Convert back to date ISO norm (str)

# %%
df_plot['date'] = time_idx
type(df_plot['date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df_plot.head()
# Out:
#         date  Italy  US  Spain  Germany  Korea, South
# 0 2020-01-22      0   1      0        0             1
# 1 2020-01-23      0   1      0        0             1
# 2 2020-01-24      0   2      0        0             2
# 3 2020-01-25      0   2      0        0             2
# 4 2020-01-26      0   5      0        0             3

# %%
df_plot.to_csv('../data/processed/COVID_small_flat_table.csv',sep=';',index = False)

# %% [markdown]
# ## Relational Data Model
# using Primary Key

# %%
data_path = '../data/raw/COVID-19/time_series_covid19_confirmed_global.csv'
pd_raw = pd.read_csv(data_path)
pd_raw.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  7/15/22  7/16/22  7/17/22  \
# 0        0        0        0        0  ...   183407   183445   183572
# 1        0        0        0        0  ...   293917   293917   293917
# 2        0        0        0        0  ...   266392   266424   266445
# 3        0        0        0        0  ...    44671    44671    44671
# 4        0        0        0        0  ...   101901   101901   101901
#
#    7/18/22  7/19/22  7/20/22  7/21/22  7/22/22  7/23/22  7/24/22
# 0   183687   183908   184038   184224   184360   184473   184587
# 1   293917   293917   293917   293917   293917   293917   293917
# 2   266487   266542   266591   266654   266700   266772   266839
# 3    45061    45061    45061    45326    45326    45326    45326
# 4   102209   102209   102209   102209   102301   102301   102301
#
# [5 rows x 919 columns]

# %%
pd_data_base= pd_raw.rename(columns = {'Country/Region':'country', 'Province/State':'state'})

# %%
pd_data_base = pd_data_base.drop(['Lat','Long'], axis = 1)
pd_data_base.head()
# Out:
#   state      country  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0   NaN  Afghanistan        0        0        0        0        0        0
# 1   NaN      Albania        0        0        0        0        0        0
# 2   NaN      Algeria        0        0        0        0        0        0
# 3   NaN      Andorra        0        0        0        0        0        0
# 4   NaN       Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  ...  7/15/22  7/16/22  7/17/22  7/18/22  7/19/22  \
# 0        0        0  ...   183407   183445   183572   183687   183908
# 1        0        0  ...   293917   293917   293917   293917   293917
# 2        0        0  ...   266392   266424   266445   266487   266542
# 3        0        0  ...    44671    44671    44671    45061    45061
# 4        0        0  ...   101901   101901   101901   102209   102209
#
#    7/20/22  7/21/22  7/22/22  7/23/22  7/24/22
# 0   184038   184224   184360   184473   184587
# 1   293917   293917   293917   293917   293917
# 2   266591   266654   266700   266772   266839
# 3    45061    45326    45326    45326    45326
# 4   102209   102209   102301   102301   102301
#
# [5 rows x 917 columns]

# %%
test_pd = pd_data_base.set_index(['state','country']).T
test_pd.columns
# Out:
# MultiIndex([(                           nan,          'Afghanistan'),
#             (                           nan,              'Albania'),
#             (                           nan,              'Algeria'),
#             (                           nan,              'Andorra'),
#             (                           nan,               'Angola'),
#             (                           nan,           'Antarctica'),
#             (                           nan,  'Antigua and Barbuda'),
#             (                           nan,            'Argentina'),
#             (                           nan,              'Armenia'),
#             ('Australian Capital Territory',            'Australia'),
#             ...
#             (                           nan,              'Uruguay'),
#             (                           nan,           'Uzbekistan'),
#             (                           nan,              'Vanuatu'),
#             (                           nan,            'Venezuela'),
#             (                           nan,              'Vietnam'),
#             (                           nan,   'West Bank and Gaza'),
#             (                           nan, 'Winter Olympics 2022'),
#             (                           nan,                'Yemen'),
#             (                           nan,               'Zambia'),
#             (                           nan,             'Zimbabwe')],
#            names=['state', 'country'], length=285)

# %%
test_pd.stack(level=[0,1]).reset_index()
# Out:
#         level_0              state      country          0
# 0       1/22/20                NaN  Afghanistan        0.0
# 1       1/22/20                NaN      Albania        0.0
# 2       1/22/20                NaN      Algeria        0.0
# 3       1/22/20                NaN      Andorra        0.0
# 4       1/22/20                NaN       Angola        0.0
# ...         ...                ...          ...        ...
# 260770  7/24/22  Western Australia    Australia  1038272.0
# 260771  7/24/22           Xinjiang        China     1008.0
# 260772  7/24/22              Yukon       Canada     4599.0
# 260773  7/24/22             Yunnan        China     2205.0
# 260774  7/24/22           Zhejiang        China     3194.0
#
# [260775 rows x 4 columns]

# %%
pd_relational_model=pd_data_base.set_index(['state','country']) \
                                .T                              \
                                .stack(level=[0,1])             \
                                .reset_index()                  \
                                .rename(columns={'level_0':'date',
                                                   0:'confirmed'},
                                                  )
pd_relational_model.head()
# Out:
#       date state      country  confirmed
# 0  1/22/20   NaN  Afghanistan        0.0
# 1  1/22/20   NaN      Albania        0.0
# 2  1/22/20   NaN      Algeria        0.0
# 3  1/22/20   NaN      Andorra        0.0
# 4  1/22/20   NaN       Angola        0.0

# %%
pd_relational_model.dtypes
# Out:
# date          object
# state         object
# country       object
# confirmed    float64
# dtype: object

# %%
pd_relational_model['date']=pd_relational_model.date.astype('datetime64[ns]')

# %%
pd_relational_model.dtypes
# Out:
# date         datetime64[ns]
# state                object
# country              object
# confirmed           float64
# dtype: object

# %%
pd_relational_model.to_csv('../data/processed/COVID_relational_confirmed.csv',sep=';',index = False)

# %% [markdown]
# ## Group-by apply

# %%
pd_JH_data = pd.read_csv('../data/processed/COVID_relational_confirmed.csv',sep=';',parse_dates=[0])
pd_JH_data = pd_JH_data.sort_values('date', ascending=True).reset_index(drop=True).copy()
pd_JH_data
# Out:
#              date     state               country   confirmed
# 0      2020-01-22       NaN           Afghanistan         0.0
# 1      2020-01-22       NaN                    US         1.0
# 2      2020-01-22       NaN                Uganda         0.0
# 3      2020-01-22       NaN               Ukraine         0.0
# 4      2020-01-22       NaN  United Arab Emirates         0.0
# ...           ...       ...                   ...         ...
# 260770 2022-07-24       NaN                Kosovo    245275.0
# 260771 2022-07-24       NaN          Korea, South  19247496.0
# 260772 2022-07-24       NaN          Korea, North         1.0
# 260773 2022-07-24       NaN                Latvia    852683.0
# 260774 2022-07-24  Zhejiang                 China      3194.0
#
# [260775 rows x 4 columns]

# %%
test_data=pd_JH_data[((pd_JH_data['country']=='US')|
                      (pd_JH_data['country']=='Germany'))&
                     (pd_JH_data['date']>'2020-03-20')]

# %%
test_data['state']=test_data['state'].fillna('no')
test_data
# Out:
# C:\Users\ashut\AppData\Local\Temp\ipykernel_10788\1681806567.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['state']=test_data['state'].fillna('no')
#              date state  country   confirmed
# 16825  2020-03-21    no       US     26025.0
# 16980  2020-03-21    no  Germany     16662.0
# 17112  2020-03-22    no       US     34944.0
# 17265  2020-03-22    no  Germany     18610.0
# 17396  2020-03-23    no       US     46096.0
# ...           ...   ...      ...         ...
# 260086 2022-07-22    no  Germany  30331131.0
# 260216 2022-07-23    no       US  90390185.0
# 260370 2022-07-23    no  Germany  30331133.0
# 260501 2022-07-24    no       US  90410386.0
# 260653 2022-07-24    no  Germany  30331133.0
#
# [1712 rows x 4 columns]

# %%
test_data.groupby(['country']).agg(np.max)
# Out:
#               date state   confirmed
# country
# Germany 2022-07-24    no  30331133.0
# US      2022-07-24    no  90410386.0

# %%
# %load ../src/features/build_features.py
import numpy as np
from sklearn import linear_model
reg = linear_model.LinearRegression(fit_intercept=True)
import pandas as pd

from scipy import signal


def get_doubling_time_via_regression(in_array):
    ''' Use a linear regression to approximate the doubling rate
        Parameters:
        ----------
        in_array : pandas.series
        Returns:
        ----------
        Doubling rate: double
    '''
    
#     y = np.array(in_array['confirmed'])
#     X = np.arange(len(y)).reshape(-1, 1)
    y = np.array(in_array)
    X = np.arange(-1,2).reshape(-1, 1)

    assert len(in_array)==3
    reg.fit(X,y)
    intercept=reg.intercept_
    slope=reg.coef_

    return intercept/slope

# %%
test_data.groupby(['state','country']).agg(np.max)
# Out:
#                     date   confirmed
# state country
# no    Germany 2022-07-24  30331133.0
#       US      2022-07-24  90410386.0

# %%
test_data.groupby(['state','country']).apply(get_doubling_time_via_regression)
# Out:
# state  country
# no     Germany    [-200.10696046741512]
#        US         [-101.43288469827172]
# dtype: object

# %%
# %load ../src/features/build_features.py

def rolling_reg(df_input,col='confirmed'):
    ''' Rolling Regression to approximate the doubling time'
        Parameters:
        ----------
        df_input: pd.DataFrame
        col: str
            defines the used column
        Returns:
        ----------
        result: pd.DataFrame
    '''
    days_back=3
    result=df_input[col].rolling(
                window=days_back,
                min_periods=days_back).apply(get_doubling_time_via_regression,raw=False)



    return result

# %%
test_data[['state','country','confirmed']].groupby(['state','country']).apply(rolling_reg,'confirmed')
# Out:
# state  country
# no     Germany  16980             NaN
#                 17265             NaN
#                 17549        6.427510
#                 17835        5.190573
#                 18120        6.129400
#                              ...
#        US       259361     538.072800
#                 259646     486.703188
#                 259931     562.367482
#                 260216     951.996385
#                 260501    4172.901143
# Name: confirmed, Length: 1712, dtype: float64

# %%
test_data
# Out:
#              date state  country   confirmed
# 16825  2020-03-21    no       US     26025.0
# 16980  2020-03-21    no  Germany     16662.0
# 17112  2020-03-22    no       US     34944.0
# 17265  2020-03-22    no  Germany     18610.0
# 17396  2020-03-23    no       US     46096.0
# ...           ...   ...      ...         ...
# 260086 2022-07-22    no  Germany  30331131.0
# 260216 2022-07-23    no       US  90390185.0
# 260370 2022-07-23    no  Germany  30331133.0
# 260501 2022-07-24    no       US  90410386.0
# 260653 2022-07-24    no  Germany  30331133.0
#
# [1712 rows x 4 columns]

# %% [markdown]
# ## Filtering the data with groupby apply

# %%
from scipy import signal

def savgol_filter(df_input,column='confirmed',window=5):
    ''' Savgol Filter which can be used in groupby apply function 
        it ensures that the data structure is kept'''
    window=5, 
    degree=1
    df_result=df_input
    
    filter_in=df_input[column].fillna(0) # attention with the neutral element here
    
    result=signal.savgol_filter(np.array(filter_in),
                           5, # window size used for filtering
                           1)
    df_result[column+'_filtered']=result
    return df_result

# %%
pd_DR_result=pd_JH_data[['state','country','confirmed']].groupby(['state','country']).apply(rolling_reg,'confirmed').reset_index()
pd_DR_result
# Out:
#           state country  level_2    confirmed
# 0       Alberta  Canada       16          NaN
# 1       Alberta  Canada      315          NaN
# 2       Alberta  Canada      593          NaN
# 3       Alberta  Canada      872          NaN
# 4       Alberta  Canada     1157          NaN
# ...         ...     ...      ...          ...
# 81430  Zhejiang   China   259441  6381.333333
# 81431  Zhejiang   China   259683  6382.666667
# 81432  Zhejiang   China   260011  6383.333333
# 81433  Zhejiang   China   260253  3192.666667
# 81434  Zhejiang   China   260774  3193.333333
#
# [81435 rows x 4 columns]

# %%
pd_DR_result=pd_DR_result.rename(columns={'confirmed':'confirmed_DR',
                             'level_2':'index'})
pd_DR_result.head()
# Out:
#      state country  index  confirmed_DR
# 0  Alberta  Canada     16           NaN
# 1  Alberta  Canada    315           NaN
# 2  Alberta  Canada    593           NaN
# 3  Alberta  Canada    872           NaN
# 4  Alberta  Canada   1157           NaN

# %%
pd_JH_data=pd_JH_data.reset_index()
pd_JH_data.head()

# %%
pd_result_larg=pd.merge(pd_JH_data,pd_DR_result[['index','confirmed_DR']],on=['index'],how='left')
pd_result_larg.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [102], in <cell line: 1>()
# ----> 1 pd_result_larg=pd.merge(pd_JH_data,pd_DR_result[['index','confirmed_DR']],on=['index'],how='left')
#       2 pd_result_larg.head()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\merge.py:700, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     693 self._cross = cross_col
#     695 # note this function has side effects
#     696 (
#     697     self.left_join_keys,
#     698     self.right_join_keys,
#     699     self.join_names,
# --> 700 ) = self._get_merge_keys()
#     702 # validate the merge keys dtypes. We may need to coerce
#     703 # to avoid incompatible dtypes
#     704 self._maybe_coerce_merge_keys()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\reshape\merge.py:1110, in _MergeOperation._get_merge_keys(self)
#    1108     right_keys.append(rk)
#    1109 if lk is not None:
# -> 1110     left_keys.append(left._get_label_or_level_values(lk))
#    1111     join_names.append(lk)
#    1112 else:
#    1113     # work-around for merge_asof(left_index=True)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:1840, in NDFrame._get_label_or_level_values(self, key, axis)
#    1838     values = self.axes[axis].get_level_values(key)._values
#    1839 else:
# -> 1840     raise KeyError(key)
#    1842 # Check for duplicates
#    1843 if values.ndim > 1:
#
# KeyError: 'index'

# %%
pd_filtered_result=pd_JH_data[['state','country','confirmed']].groupby(['state','country']).apply(savgol_filter).reset_index()

# %%
pd_result_larg=pd.merge(pd_result_larg,pd_filtered_result[['index','confirmed_filtered']],on=['index'],how='left')
pd_result_larg.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [93], in <cell line: 1>()
# ----> 1 pd_result_larg=pd.merge(pd_result_larg,pd_filtered_result[['index','confirmed_filtered']],on=['index'],how='left')
#       2 pd_result_larg.head()
#
# NameError: name 'pd_result_larg' is not defined
